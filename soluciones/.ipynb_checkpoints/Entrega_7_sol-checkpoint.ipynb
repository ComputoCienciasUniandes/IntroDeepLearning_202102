# %%
#-- Descomprimimos el dataset
# !rm -r mnist
# !unzip /content/drive/MyDrive/Colab/IntroDeepLearning_202102/fashion-mnist.zip
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#   inflating: fashion-mnist/test/0/2423.png
#   inflating: fashion-mnist/test/0/444.png
#   inflating: fashion-mnist/test/0/965.png
#   inflating: fashion-mnist/test/0/1460.png
#   inflating: fashion-mnist/test/0/3440.png
#   inflating: fashion-mnist/test/0/2795.png
#   inflating: fashion-mnist/test/0/2474.png
#   inflating: fashion-mnist/test/0/169.png
#   inflating: fashion-mnist/test/0/1647.png
#   inflating: fashion-mnist/test/0/2121.png
#   inflating: fashion-mnist/test/0/2163.png
#   inflating: fashion-mnist/test/0/2753.png
#   inflating: fashion-mnist/test/0/645.png
#   inflating: fashion-mnist/test/0/34.png
#   inflating: fashion-mnist/test/0/716.png
#   inflating: fashion-mnist/test/0/3874.png
#   inflating: fashion-mnist/test/0/3128.png
#   inflating: fashion-mnist/test/0/2180.png
#   inflating: fashion-mnist/test/0/2439.png
#   inflating: fashion-mnist/test/0/269.png
#   inflating: fashion-mnist/test/0/2027.png
#   inflating: fashion-mnist/test/0/5357.png
#   inflating: fashion-mnist/test/0/5290.png
#   inflating: fashion-mnist/test/0/1929.png
#   inflating: fashion-mnist/test/0/176.png
#   inflating: fashion-mnist/test/0/160.png
#   inflating: fashion-mnist/test/0/1390.png
#   inflating: fashion-mnist/test/0/2911.png
#   inflating: fashion-mnist/test/0/3237.png
#   inflating: fashion-mnist/test/0/1877.png
#   inflating: fashion-mnist/test/0/877.png
#   inflating: fashion-mnist/test/0/1681.png
#   inflating: fashion-mnist/test/0/4575.png
#   inflating: fashion-mnist/test/0/445.png
#   inflating: fashion-mnist/test/0/171.png
#   inflating: fashion-mnist/test/0/3743.png
#   inflating: fashion-mnist/test/0/4889.png
#   inflating: fashion-mnist/test/0/1301.png
#   inflating: fashion-mnist/test/0/1589.png
#   inflating: fashion-mnist/test/0/4818.png
#   inflating: fashion-mnist/test/0/2420.png
#   inflating: fashion-mnist/test/0/3499.png
#   inflating: fashion-mnist/test/0/592.png
#   inflating: fashion-mnist/test/0/237.png
#   inflating: fashion-mnist/test/0/383.png
#   inflating: fashion-mnist/test/0/1950.png
#   inflating: fashion-mnist/test/0/4388.png
#   inflating: fashion-mnist/test/0/5265.png
#   inflating: fashion-mnist/test/0/2960.png
#   inflating: fashion-mnist/test/0/5400.png
#   inflating: fashion-mnist/test/0/1608.png
#   inflating: fashion-mnist/test/0/639.png
#   inflating: fashion-mnist/test/0/2334.png
#   inflating: fashion-mnist/test/0/837.png
#   inflating: fashion-mnist/test/0/715.png
#   inflating: fashion-mnist/test/0/3089.png
#   inflating: fashion-mnist/test/0/304.png
#   inflating: fashion-mnist/test/0/3915.png
#   inflating: fashion-mnist/test/0/3815.png
#   inflating: fashion-mnist/test/0/5119.png
#   inflating: fashion-mnist/test/0/1013.png
#   inflating: fashion-mnist/test/0/2138.png
#   inflating: fashion-mnist/test/0/641.png
#   inflating: fashion-mnist/test/0/3644.png
#   inflating: fashion-mnist/test/0/519.png
#   inflating: fashion-mnist/test/0/5235.png
#   inflating: fashion-mnist/test/0/4946.png
#   inflating: fashion-mnist/test/0/2041.png
#   inflating: fashion-mnist/test/0/441.png
#   inflating: fashion-mnist/test/0/3405.png
#   inflating: fashion-mnist/test/0/1907.png
#   inflating: fashion-mnist/test/0/1071.png
#   inflating: fashion-mnist/test/0/5401.png
#   inflating: fashion-mnist/test/0/1084.png
#   inflating: fashion-mnist/test/0/1041.png
#   inflating: fashion-mnist/test/0/4871.png
#   inflating: fashion-mnist/test/0/4138.png
#   inflating: fashion-mnist/test/0/4680.png
#   inflating: fashion-mnist/test/0/4455.png
#   inflating: fashion-mnist/test/0/3761.png
#   inflating: fashion-mnist/test/0/3379.png
#   inflating: fashion-mnist/test/0/3679.png
#   inflating: fashion-mnist/test/0/4704.png
#   inflating: fashion-mnist/test/0/4546.png
#   inflating: fashion-mnist/test/0/186.png
#   inflating: fashion-mnist/test/0/5320.png
#   inflating: fashion-mnist/test/0/564.png
#   inflating: fashion-mnist/test/0/302.png
#   inflating: fashion-mnist/test/0/1430.png
#   inflating: fashion-mnist/test/0/4796.png
#   inflating: fashion-mnist/test/0/2289.png
#   inflating: fashion-mnist/test/0/3560.png
#   inflating: fashion-mnist/test/0/48.png
#   inflating: fashion-mnist/test/0/4134.png
#   inflating: fashion-mnist/test/0/4507.png
#   inflating: fashion-mnist/test/0/4240.png
#   inflating: fashion-mnist/test/0/3674.png
#   inflating: fashion-mnist/test/0/3777.png
#   inflating: fashion-mnist/test/0/789.png
#   inflating: fashion-mnist/test/0/3911.png
#   inflating: fashion-mnist/test/0/1634.png
#   inflating: fashion-mnist/test/0/3041.png
#   inflating: fashion-mnist/test/0/5070.png
#   inflating: fashion-mnist/test/0/2745.png
#   inflating: fashion-mnist/test/0/4544.png
#   inflating: fashion-mnist/test/0/858.png
#   inflating: fashion-mnist/test/0/1327.png
#   inflating: fashion-mnist/test/0/4428.png
#   inflating: fashion-mnist/test/0/2594.png
#   inflating: fashion-mnist/test/0/1073.png
#   inflating: fashion-mnist/test/0/829.png
#   inflating: fashion-mnist/test/0/972.png
#   inflating: fashion-mnist/test/0/4821.png
#   inflating: fashion-mnist/test/0/272.png
#   inflating: fashion-mnist/test/0/5272.png
#   inflating: fashion-mnist/test/0/3340.png
#   inflating: fashion-mnist/test/0/3903.png
#   inflating: fashion-mnist/test/0/3791.png
#   inflating: fashion-mnist/test/0/1005.png
#   inflating: fashion-mnist/test/0/1846.png
#   inflating: fashion-mnist/test/0/2127.png
#   inflating: fashion-mnist/test/0/1897.png
#   inflating: fashion-mnist/test/0/4743.png
#   inflating: fashion-mnist/test/0/325.png
#   inflating: fashion-mnist/test/0/5137.png
#   inflating: fashion-mnist/test/0/4322.png
#   inflating: fashion-mnist/test/0/1308.png
#   inflating: fashion-mnist/test/0/4847.png
#   inflating: fashion-mnist/test/0/3548.png
#   inflating: fashion-mnist/test/0/910.png
#   inflating: fashion-mnist/test/0/825.png
#   inflating: fashion-mnist/test/0/489.png
#   inflating: fashion-mnist/test/0/3358.png
#   inflating: fashion-mnist/test/0/67.png
#   inflating: fashion-mnist/test/0/1202.png
#   inflating: fashion-mnist/test/0/3227.png
#   inflating: fashion-mnist/test/0/3620.png
#   inflating: fashion-mnist/test/0/2994.png
#   inflating: fashion-mnist/test/0/3470.png
#   inflating: fashion-mnist/test/0/1855.png
#   inflating: fashion-mnist/test/0/64.png
#   inflating: fashion-mnist/test/0/1503.png
#   inflating: fashion-mnist/test/0/2315.png
#   inflating: fashion-mnist/test/0/3864.png
#   inflating: fashion-mnist/test/0/4380.png
#   inflating: fashion-mnist/test/0/5051.png
#   inflating: fashion-mnist/test/0/1516.png
#   inflating: fashion-mnist/test/0/1396.png
#   inflating: fashion-mnist/test/0/2060.png
#   inflating: fashion-mnist/test/0/1682.png
#   inflating: fashion-mnist/test/0/5038.png
#   inflating: fashion-mnist/test/0/154.png
#   inflating: fashion-mnist/test/0/1288.png
#   inflating: fashion-mnist/test/0/4238.png
#   inflating: fashion-mnist/test/0/3637.png
#   inflating: fashion-mnist/test/0/812.png
#   inflating: fashion-mnist/test/0/2654.png
#   inflating: fashion-mnist/test/0/2372.png
#   inflating: fashion-mnist/test/0/2582.png
#   inflating: fashion-mnist/test/0/61.png
#   inflating: fashion-mnist/test/0/3432.png
#   inflating: fashion-mnist/test/0/4957.png
#   inflating: fashion-mnist/test/0/1884.png
#   inflating: fashion-mnist/test/0/3219.png
#   inflating: fashion-mnist/test/0/4224.png
#   inflating: fashion-mnist/test/0/1547.png
#   inflating: fashion-mnist/test/0/1971.png
#   inflating: fashion-mnist/test/0/2367.png
#   inflating: fashion-mnist/test/0/3617.png
#   inflating: fashion-mnist/test/0/2833.png
#   inflating: fashion-mnist/test/0/3741.png
#   inflating: fashion-mnist/test/0/2459.png
#   inflating: fashion-mnist/test/0/1311.png
#   inflating: fashion-mnist/test/0/5268.png
#   inflating: fashion-mnist/test/0/3205.png
#   inflating: fashion-mnist/test/0/662.png
#   inflating: fashion-mnist/test/0/4648.png
#   inflating: fashion-mnist/test/0/3711.png
#   inflating: fashion-mnist/test/0/4634.png
#   inflating: fashion-mnist/test/0/3829.png
#   inflating: fashion-mnist/test/0/5028.png
#   inflating: fashion-mnist/test/0/591.png
#   inflating: fashion-mnist/test/0/3333.png
#   inflating: fashion-mnist/test/0/2213.png
#   inflating: fashion-mnist/test/0/3966.png
#   inflating: fashion-mnist/test/0/182.png
#   inflating: fashion-mnist/test/0/530.png
#   inflating: fashion-mnist/test/0/17.png
#   inflating: fashion-mnist/test/0/3154.png
#   inflating: fashion-mnist/test/0/2363.png
#   inflating: fashion-mnist/test/0/3090.png
#   inflating: fashion-mnist/test/0/4407.png
#   inflating: fashion-mnist/test/0/1912.png
#   inflating: fashion-mnist/test/0/771.png
#   inflating: fashion-mnist/test/0/329.png
#   inflating: fashion-mnist/test/0/331.png
#   inflating: fashion-mnist/test/0/2896.png
#   inflating: fashion-mnist/test/0/712.png
#   inflating: fashion-mnist/test/0/3485.png
#   inflating: fashion-mnist/test/0/5001.png
#   inflating: fashion-mnist/test/0/3373.png
#   inflating: fashion-mnist/test/0/1254.png
#   inflating: fashion-mnist/test/0/732.png
#   inflating: fashion-mnist/test/0/2133.png
#   inflating: fashion-mnist/test/0/2809.png
#   inflating: fashion-mnist/test/0/942.png
#   inflating: fashion-mnist/test/0/4283.png
#   inflating: fashion-mnist/test/0/4052.png
#   inflating: fashion-mnist/test/0/3767.png
#   inflating: fashion-mnist/test/0/2190.png
#   inflating: fashion-mnist/test/0/2428.png
#   inflating: fashion-mnist/test/0/2350.png
#   inflating: fashion-mnist/test/0/2984.png
#   inflating: fashion-mnist/test/0/3048.png
#   inflating: fashion-mnist/test/0/1707.png
#   inflating: fashion-mnist/test/0/2695.png
#   inflating: fashion-mnist/test/0/4766.png
#   inflating: fashion-mnist/test/0/3512.png
#   inflating: fashion-mnist/test/0/1104.png
#   inflating: fashion-mnist/test/0/3137.png
#   inflating: fashion-mnist/test/0/3072.png
#   inflating: fashion-mnist/test/0/1098.png
#   inflating: fashion-mnist/test/0/5099.png
#   inflating: fashion-mnist/test/0/522.png
#   inflating: fashion-mnist/test/0/3686.png
#   inflating: fashion-mnist/test/0/3992.png
#   inflating: fashion-mnist/test/0/4048.png
#   inflating: fashion-mnist/test/0/1731.png
#   inflating: fashion-mnist/test/0/4960.png
#   inflating: fashion-mnist/test/0/4947.png
#   inflating: fashion-mnist/test/0/3233.png
#   inflating: fashion-mnist/test/0/791.png
#   inflating: fashion-mnist/test/0/222.png
#   inflating: fashion-mnist/test/0/3543.png
#   inflating: fashion-mnist/test/0/3524.png
#   inflating: fashion-mnist/test/0/1479.png
#   inflating: fashion-mnist/test/0/816.png
#   inflating: fashion-mnist/test/0/3221.png
#   inflating: fashion-mnist/test/0/4101.png
#   inflating: fashion-mnist/test/0/3534.png
#   inflating: fashion-mnist/test/0/5266.png
#   inflating: fashion-mnist/test/0/3155.png
#   inflating: fashion-mnist/test/0/3906.png
#   inflating: fashion-mnist/test/0/4274.png
#   inflating: fashion-mnist/test/0/3009.png
#   inflating: fashion-mnist/test/0/3416.png
#   inflating: fashion-mnist/test/0/2832.png
#   inflating: fashion-mnist/test/0/2938.png
#   inflating: fashion-mnist/test/0/2318.png
#   inflating: fashion-mnist/test/0/1031.png
#   inflating: fashion-mnist/test/0/504.png
#   inflating: fashion-mnist/test/0/1989.png
#   inflating: fashion-mnist/test/0/207.png
#   inflating: fashion-mnist/test/0/4585.png
#   inflating: fashion-mnist/test/0/3086.png
#   inflating: fashion-mnist/test/0/1837.png
#   inflating: fashion-mnist/test/0/1861.png
#   inflating: fashion-mnist/test/0/429.png
#   inflating: fashion-mnist/test/0/2198.png
#   inflating: fashion-mnist/test/0/600.png
#   inflating: fashion-mnist/test/0/4611.png
#   inflating: fashion-mnist/test/0/4499.png
#   inflating: fashion-mnist/test/0/1581.png
#   inflating: fashion-mnist/test/0/5365.png
#   inflating: fashion-mnist/test/0/2526.png
#   inflating: fashion-mnist/test/0/1821.png
#   inflating: fashion-mnist/test/0/892.png
#   inflating: fashion-mnist/test/0/2975.png
#   inflating: fashion-mnist/test/0/1622.png
#   inflating: fashion-mnist/test/0/700.png
#   inflating: fashion-mnist/test/0/1056.png
#   inflating: fashion-mnist/test/0/4691.png
#   inflating: fashion-mnist/test/0/4581.png
#   inflating: fashion-mnist/test/0/3759.png
#   inflating: fashion-mnist/test/0/377.png
#   inflating: fashion-mnist/test/0/4835.png
#   inflating: fashion-mnist/test/0/1843.png
#   inflating: fashion-mnist/test/0/66.png
#   inflating: fashion-mnist/test/0/5402.png
#   inflating: fashion-mnist/test/0/2303.png
#   inflating: fashion-mnist/test/0/5141.png
#   inflating: fashion-mnist/test/0/1727.png
#   inflating: fashion-mnist/test/0/2615.png
#   inflating: fashion-mnist/test/0/4784.png
#   inflating: fashion-mnist/test/0/3655.png
#   inflating: fashion-mnist/test/0/1264.png
#   inflating: fashion-mnist/test/0/3064.png
#   inflating: fashion-mnist/test/0/967.png
#   inflating: fashion-mnist/test/0/1791.png
#   inflating: fashion-mnist/test/0/2.png
#   inflating: fashion-mnist/test/0/3952.png
#   inflating: fashion-mnist/test/0/905.png
#   inflating: fashion-mnist/test/0/191.png
#   inflating: fashion-mnist/test/0/665.png
#   inflating: fashion-mnist/test/0/2944.png
#   inflating: fashion-mnist/test/0/2601.png
#   inflating: fashion-mnist/test/0/5175.png
#   inflating: fashion-mnist/test/0/2875.png
#   inflating: fashion-mnist/test/0/2062.png
#   inflating: fashion-mnist/test/0/5358.png
#   inflating: fashion-mnist/test/0/3472.png
#   inflating: fashion-mnist/test/0/2471.png
#   inflating: fashion-mnist/test/0/4685.png
#   inflating: fashion-mnist/test/0/1590.png
#   inflating: fashion-mnist/test/0/4879.png
#   inflating: fashion-mnist/test/0/808.png
#   inflating: fashion-mnist/test/0/2426.png
#   inflating: fashion-mnist/test/0/1170.png
#   inflating: fashion-mnist/test/0/678.png
#   inflating: fashion-mnist/test/0/1809.png
#   inflating: fashion-mnist/test/0/1850.png
#   inflating: fashion-mnist/test/0/219.png
#   inflating: fashion-mnist/test/0/1155.png
#   inflating: fashion-mnist/test/0/2286.png
#   inflating: fashion-mnist/test/0/5094.png
#   inflating: fashion-mnist/test/0/3345.png
#   inflating: fashion-mnist/test/0/4511.png
#   inflating: fashion-mnist/test/0/10.png
#   inflating: fashion-mnist/test/0/1410.png
#   inflating: fashion-mnist/test/0/149.png
#   inflating: fashion-mnist/test/0/4724.png
#   inflating: fashion-mnist/test/0/4558.png
#   inflating: fashion-mnist/test/0/3553.png
#   inflating: fashion-mnist/test/0/823.png
#   inflating: fashion-mnist/test/0/2374.png
#   inflating: fashion-mnist/test/0/1103.png
#   inflating: fashion-mnist/test/0/1800.png
#   inflating: fashion-mnist/test/0/1525.png
#   inflating: fashion-mnist/test/0/1329.png
#   inflating: fashion-mnist/test/0/745.png
#   inflating: fashion-mnist/test/0/3130.png
#   inflating: fashion-mnist/test/0/1526.png
#   inflating: fashion-mnist/test/0/5298.png
#   inflating: fashion-mnist/test/0/4234.png
#   inflating: fashion-mnist/test/0/5074.png
#   inflating: fashion-mnist/test/0/3667.png
#   inflating: fashion-mnist/test/0/1.png
#   inflating: fashion-mnist/test/0/4012.png
#   inflating: fashion-mnist/test/0/2049.png
#   inflating: fashion-mnist/test/0/5138.png
#   inflating: fashion-mnist/test/0/880.png
#   inflating: fashion-mnist/test/0/1560.png
#   inflating: fashion-mnist/test/0/4695.png
#   inflating: fashion-mnist/test/0/3375.png
#   inflating: fashion-mnist/test/0/4684.png
#   inflating: fashion-mnist/test/0/741.png
#   inflating: fashion-mnist/test/0/4085.png
#   inflating: fashion-mnist/test/0/5202.png
#   inflating: fashion-mnist/test/0/5254.png
#   inflating: fashion-mnist/test/0/1895.png
#   inflating: fashion-mnist/test/0/3070.png
#   inflating: fashion-mnist/test/0/4681.png
#   inflating: fashion-mnist/test/0/2759.png
#   inflating: fashion-mnist/test/0/2307.png
#   inflating: fashion-mnist/test/0/830.png
#   inflating: fashion-mnist/test/0/1473.png
#   inflating: fashion-mnist/test/0/2431.png
#   inflating: fashion-mnist/test/0/3968.png
#   inflating: fashion-mnist/test/0/2159.png
#   inflating: fashion-mnist/test/0/988.png
#   inflating: fashion-mnist/test/0/565.png
#   inflating: fashion-mnist/test/0/1748.png
#   inflating: fashion-mnist/test/0/2105.png
#   inflating: fashion-mnist/test/0/3832.png
#   inflating: fashion-mnist/test/0/1158.png
#   inflating: fashion-mnist/test/0/338.png
#   inflating: fashion-mnist/test/0/1110.png
#   inflating: fashion-mnist/test/0/2730.png
#   inflating: fashion-mnist/test/0/849.png
#   inflating: fashion-mnist/test/0/4125.png
#   inflating: fashion-mnist/test/0/1737.png
#   inflating: fashion-mnist/test/0/5353.png
#   inflating: fashion-mnist/test/0/2437.png
#   inflating: fashion-mnist/test/0/5114.png
#   inflating: fashion-mnist/test/0/1489.png
#   inflating: fashion-mnist/test/0/2058.png
#   inflating: fashion-mnist/test/0/4061.png
#   inflating: fashion-mnist/test/0/2310.png
#   inflating: fashion-mnist/test/0/2479.png
#   inflating: fashion-mnist/test/0/5329.png
#   inflating: fashion-mnist/test/0/2167.png
#   inflating: fashion-mnist/test/0/4210.png
#   inflating: fashion-mnist/test/0/3948.png
#   inflating: fashion-mnist/test/0/493.png
#   inflating: fashion-mnist/test/0/2741.png
#   inflating: fashion-mnist/test/0/4117.png
#   inflating: fashion-mnist/test/0/101.png
#   inflating: fashion-mnist/test/0/2712.png
#   inflating: fashion-mnist/test/0/5178.png
#   inflating: fashion-mnist/test/0/1603.png
#   inflating: fashion-mnist/test/0/2772.png
#   inflating: fashion-mnist/test/0/3564.png
#   inflating: fashion-mnist/test/0/5200.png
#   inflating: fashion-mnist/test/0/3305.png
#   inflating: fashion-mnist/test/0/4057.png
#   inflating: fashion-mnist/test/0/202.png
#   inflating: fashion-mnist/test/0/4703.png
#   inflating: fashion-mnist/test/0/4325.png
#   inflating: fashion-mnist/test/0/5196.png
#   inflating: fashion-mnist/test/0/1303.png
#   inflating: fashion-mnist/test/0/2523.png
#   inflating: fashion-mnist/test/0/4839.png
#   inflating: fashion-mnist/test/0/601.png
#   inflating: fashion-mnist/test/0/5368.png
#   inflating: fashion-mnist/test/0/2410.png
#   inflating: fashion-mnist/test/0/448.png
#   inflating: fashion-mnist/test/0/180.png
#   inflating: fashion-mnist/test/0/392.png
#   inflating: fashion-mnist/test/0/2070.png
#   inflating: fashion-mnist/test/0/4932.png
#   inflating: fashion-mnist/test/0/3076.png
#   inflating: fashion-mnist/test/0/1325.png
#   inflating: fashion-mnist/test/0/4226.png
#   inflating: fashion-mnist/test/0/2155.png
#   inflating: fashion-mnist/test/0/3964.png
#   inflating: fashion-mnist/test/0/4461.png
#   inflating: fashion-mnist/test/0/1169.png
#   inflating: fashion-mnist/test/0/3980.png
#   inflating: fashion-mnist/test/0/2118.png
#   inflating: fashion-mnist/test/0/5309.png
#   inflating: fashion-mnist/test/0/4853.png
#   inflating: fashion-mnist/test/0/187.png
#   inflating: fashion-mnist/test/0/3050.png
#   inflating: fashion-mnist/test/0/1815.png
#   inflating: fashion-mnist/test/0/3865.png
#   inflating: fashion-mnist/test/0/1942.png
#   inflating: fashion-mnist/test/0/3078.png
#   inflating: fashion-mnist/test/0/4862.png
#   inflating: fashion-mnist/test/0/1698.png
#   inflating: fashion-mnist/test/0/1424.png
#   inflating: fashion-mnist/test/0/1536.png
#   inflating: fashion-mnist/test/0/976.png
#   inflating: fashion-mnist/test/0/438.png
#   inflating: fashion-mnist/test/0/1599.png
#   inflating: fashion-mnist/test/0/3242.png
#   inflating: fashion-mnist/test/0/3197.png
#   inflating: fashion-mnist/test/0/780.png
#   inflating: fashion-mnist/test/0/3922.png
#   inflating: fashion-mnist/test/0/4389.png
#   inflating: fashion-mnist/test/0/4.png
#   inflating: fashion-mnist/test/0/5247.png
#   inflating: fashion-mnist/test/0/1228.png
#   inflating: fashion-mnist/test/0/5045.png
#   inflating: fashion-mnist/test/0/4868.png
#   inflating: fashion-mnist/test/0/839.png
#   inflating: fashion-mnist/test/0/2621.png
#   inflating: fashion-mnist/test/0/225.png
#   inflating: fashion-mnist/test/0/516.png
#   inflating: fashion-mnist/test/0/4330.png
#   inflating: fashion-mnist/test/0/3079.png
#   inflating: fashion-mnist/test/0/4363.png
#   inflating: fashion-mnist/test/0/5010.png
#   inflating: fashion-mnist/test/0/415.png
#   inflating: fashion-mnist/test/0/4261.png
#   inflating: fashion-mnist/test/0/3991.png
#   inflating: fashion-mnist/test/0/4884.png
#   inflating: fashion-mnist/test/0/2266.png
#   inflating: fashion-mnist/test/0/4390.png
#   inflating: fashion-mnist/test/0/3717.png
#   inflating: fashion-mnist/test/0/4971.png
#   inflating: fashion-mnist/test/0/2962.png
#   inflating: fashion-mnist/test/0/815.png
#   inflating: fashion-mnist/test/0/1956.png
#   inflating: fashion-mnist/test/0/321.png
#   inflating: fashion-mnist/test/0/3592.png
#   inflating: fashion-mnist/test/0/2698.png
#   inflating: fashion-mnist/test/0/354.png
#   inflating: fashion-mnist/test/0/4177.png
#   inflating: fashion-mnist/test/0/4817.png
#   inflating: fashion-mnist/test/0/2189.png
#   inflating: fashion-mnist/test/0/4712.png
#   inflating: fashion-mnist/test/0/1218.png
#   inflating: fashion-mnist/test/0/2238.png
#   inflating: fashion-mnist/test/0/2300.png
#   inflating: fashion-mnist/test/0/2887.png
#   inflating: fashion-mnist/test/0/3325.png
#   inflating: fashion-mnist/test/1/3998.png
#   inflating: fashion-mnist/test/1/3990.png
#   inflating: fashion-mnist/test/1/2569.png
#   inflating: fashion-mnist/test/1/1625.png
#   inflating: fashion-mnist/test/1/2117.png
#   inflating: fashion-mnist/test/1/718.png
#   inflating: fashion-mnist/test/1/4103.png
#   inflating: fashion-mnist/test/1/2421.png
#   inflating: fashion-mnist/test/1/1141.png
#   inflating: fashion-mnist/test/1/283.png
#   inflating: fashion-mnist/test/1/959.png
#   inflating: fashion-mnist/test/1/2874.png
#   inflating: fashion-mnist/test/1/3616.png
#   inflating: fashion-mnist/test/1/2676.png
#   inflating: fashion-mnist/test/1/3126.png
#   inflating: fashion-mnist/test/1/723.png
#   inflating: fashion-mnist/test/1/4093.png
#   inflating: fashion-mnist/test/1/1286.png
#   inflating: fashion-mnist/test/1/385.png
#   inflating: fashion-mnist/test/1/86.png
#   inflating: fashion-mnist/test/1/106.png
#   inflating: fashion-mnist/test/1/704.png
#   inflating: fashion-mnist/test/1/2697.png
#   inflating: fashion-mnist/test/1/3622.png
#   inflating: fashion-mnist/test/1/1605.png
#   inflating: fashion-mnist/test/1/2343.png
#   inflating: fashion-mnist/test/1/4350.png
#   inflating: fashion-mnist/test/1/3729.png
#   inflating: fashion-mnist/test/1/2237.png
#   inflating: fashion-mnist/test/1/1394.png
#   inflating: fashion-mnist/test/1/1024.png
#   inflating: fashion-mnist/test/1/4392.png
#   inflating: fashion-mnist/test/1/917.png
#   inflating: fashion-mnist/test/1/2071.png
#   inflating: fashion-mnist/test/1/3724.png
#   inflating: fashion-mnist/test/1/460.png
#   inflating: fashion-mnist/test/1/414.png
#    creating: fashion-mnist/test/2/
#   inflating: fashion-mnist/test/2/2192.png
#   inflating: fashion-mnist/test/2/4500.png
#   inflating: fashion-mnist/test/2/1881.png
#   inflating: fashion-mnist/test/2/4383.png
#   inflating: fashion-mnist/test/2/3502.png
#   inflating: fashion-mnist/test/2/4168.png
#   inflating: fashion-mnist/test/2/4907.png
#   inflating: fashion-mnist/test/2/3174.png
#   inflating: fashion-mnist/test/2/3950.png
#   inflating: fashion-mnist/test/2/4009.png
#   inflating: fashion-mnist/test/2/1923.png
#   inflating: fashion-mnist/test/2/1515.png
#   inflating: fashion-mnist/test/2/1428.png
#   inflating: fashion-mnist/test/2/234.png
#   inflating: fashion-mnist/test/2/4720.png
#   inflating: fashion-mnist/test/2/2678.png
#   inflating: fashion-mnist/test/2/1928.png
#   inflating: fashion-mnist/test/2/2624.png
#   inflating: fashion-mnist/test/2/1389.png
#   inflating: fashion-mnist/test/2/2016.png
#   inflating: fashion-mnist/test/2/2572.png
#   inflating: fashion-mnist/test/2/3002.png
#   inflating: fashion-mnist/test/2/4375.png
#   inflating: fashion-mnist/test/2/2025.png
#   inflating: fashion-mnist/test/2/2876.png
#   inflating: fashion-mnist/test/2/440.png
#   inflating: fashion-mnist/test/2/1319.png
#   inflating: fashion-mnist/test/2/580.png
#   inflating: fashion-mnist/test/2/2259.png
#   inflating: fashion-mnist/test/2/2618.png
#   inflating: fashion-mnist/test/2/4317.png
#   inflating: fashion-mnist/test/2/4677.png
#   inflating: fashion-mnist/test/2/65.png
#   inflating: fashion-mnist/test/2/3923.png
#   inflating: fashion-mnist/test/2/1452.png
#   inflating: fashion-mnist/test/2/228.png
#   inflating: fashion-mnist/test/2/3750.png
#   inflating: fashion-mnist/test/2/4494.png
#   inflating: fashion-mnist/test/2/4327.png
#   inflating: fashion-mnist/test/2/484.png
#   inflating: fashion-mnist/test/2/2109.png
#   inflating: fashion-mnist/test/2/3519.png
#   inflating: fashion-mnist/test/2/1597.png
#   inflating: fashion-mnist/test/2/4414.png
#   inflating: fashion-mnist/test/2/3710.png
#   inflating: fashion-mnist/test/2/3419.png
#   inflating: fashion-mnist/test/2/1215.png
#   inflating: fashion-mnist/test/2/4693.png
#   inflating: fashion-mnist/test/2/3119.png
#   inflating: fashion-mnist/test/2/3111.png
#   inflating: fashion-mnist/test/2/3510.png
#   inflating: fashion-mnist/test/2/616.png
#   inflating: fashion-mnist/test/2/1641.png
#   inflating: fashion-mnist/test/2/3853.png
#   inflating: fashion-mnist/test/2/985.png
#   inflating: fashion-mnist/test/2/3151.png
#   inflating: fashion-mnist/test/2/3370.png
#   inflating: fashion-mnist/test/2/2223.png
#   inflating: fashion-mnist/test/2/2965.png
#   inflating: fashion-mnist/test/2/4310.png
#   inflating: fashion-mnist/test/2/2856.png
#   inflating: fashion-mnist/test/2/981.png
#   inflating: fashion-mnist/test/2/273.png
#   inflating: fashion-mnist/test/2/2417.png
#   inflating: fashion-mnist/test/2/4888.png
#   inflating: fashion-mnist/test/2/1440.png
#   inflating: fashion-mnist/test/2/1799.png
#   inflating: fashion-mnist/test/2/4491.png
#   inflating: fashion-mnist/test/2/2116.png
#   inflating: fashion-mnist/test/2/4005.png
#   inflating: fashion-mnist/test/2/1393.png
#   inflating: fashion-mnist/test/2/3749.png
#   inflating: fashion-mnist/test/2/276.png
#   inflating: fashion-mnist/test/2/505.png
#   inflating: fashion-mnist/test/2/4445.png
#   inflating: fashion-mnist/test/2/3313.png
#   inflating: fashion-mnist/test/2/2454.png
#   inflating: fashion-mnist/test/2/1702.png
# ...
#   inflating: fashion-mnist/test/9/434.png
#   inflating: fashion-mnist/test/9/4263.png
#   inflating: fashion-mnist/test/9/608.png
#   inflating: fashion-mnist/test/9/1241.png
#   inflating: fashion-mnist/test/9/3520.png
#   inflating: fashion-mnist/test/9/719.png
#   inflating: fashion-mnist/test/9/4656.png
#   inflating: fashion-mnist/test/9/3537.png
#   inflating: fashion-mnist/test/9/924.png
#   inflating: fashion-mnist/test/9/570.png
#   inflating: fashion-mnist/test/9/1591.png
#   inflating: fashion-mnist/test/9/4419.png
#   inflating: fashion-mnist/test/9/3460.png
#   inflating: fashion-mnist/test/9/1079.png
#   inflating: fashion-mnist/test/9/4749.png
#   inflating: fashion-mnist/test/9/2671.png
#   inflating: fashion-mnist/test/9/360.png
#   inflating: fashion-mnist/test/9/2836.png
#   inflating: fashion-mnist/test/9/1060.png
#   inflating: fashion-mnist/test/9/866.png
#   inflating: fashion-mnist/test/9/4326.png
#   inflating: fashion-mnist/test/9/2689.png
#   inflating: fashion-mnist/test/9/2530.png
#   inflating: fashion-mnist/test/9/1034.png
#   inflating: fashion-mnist/test/9/3868.png
#   inflating: fashion-mnist/test/9/4918.png
#   inflating: fashion-mnist/test/9/4844.png
#   inflating: fashion-mnist/test/9/3092.png
#   inflating: fashion-mnist/test/9/4542.png
#   inflating: fashion-mnist/test/9/4306.png
#   inflating: fashion-mnist/test/9/2890.png
#   inflating: fashion-mnist/test/9/3506.png
#   inflating: fashion-mnist/test/9/2442.png
#   inflating: fashion-mnist/test/9/2365.png
#   inflating: fashion-mnist/test/9/42.png
#   inflating: fashion-mnist/test/9/510.png
#   inflating: fashion-mnist/test/9/3304.png
#   inflating: fashion-mnist/test/9/573.png
#   inflating: fashion-mnist/test/9/4667.png
#   inflating: fashion-mnist/test/9/3464.png
#   inflating: fashion-mnist/test/9/1258.png
#   inflating: fashion-mnist/test/9/3232.png
#   inflating: fashion-mnist/test/9/1185.png
#   inflating: fashion-mnist/test/9/4442.png
#   inflating: fashion-mnist/test/9/1705.png
#   inflating: fashion-mnist/test/9/390.png
#   inflating: fashion-mnist/test/9/4528.png
#   inflating: fashion-mnist/test/9/1467.png
#   inflating: fashion-mnist/test/9/680.png
#   inflating: fashion-mnist/test/9/4022.png
#   inflating: fashion-mnist/test/9/2197.png
#   inflating: fashion-mnist/test/9/1573.png
#   inflating: fashion-mnist/test/9/2252.png
#   inflating: fashion-mnist/test/9/4713.png
#   inflating: fashion-mnist/test/9/2727.png
#   inflating: fashion-mnist/test/9/4427.png
#   inflating: fashion-mnist/test/9/3676.png
#   inflating: fashion-mnist/test/9/3763.png
#   inflating: fashion-mnist/test/9/1616.png
#   inflating: fashion-mnist/test/9/295.png
#   inflating: fashion-mnist/test/9/3483.png
#   inflating: fashion-mnist/test/9/1842.png
#   inflating: fashion-mnist/test/9/1465.png
#   inflating: fashion-mnist/test/9/2156.png
#   inflating: fashion-mnist/test/9/4471.png
#   inflating: fashion-mnist/test/9/624.png
#   inflating: fashion-mnist/test/9/3121.png
#   inflating: fashion-mnist/test/9/3647.png
#   inflating: fashion-mnist/test/9/4249.png
#   inflating: fashion-mnist/test/9/3511.png
#   inflating: fashion-mnist/test/9/4490.png
#   inflating: fashion-mnist/test/9/2032.png
#   inflating: fashion-mnist/test/9/1416.png
#   inflating: fashion-mnist/test/9/1637.png
#   inflating: fashion-mnist/test/9/3921.png
#   inflating: fashion-mnist/test/9/1040.png
#   inflating: fashion-mnist/test/9/3599.png
#   inflating: fashion-mnist/test/9/2306.png
#   inflating: fashion-mnist/test/9/1777.png
#   inflating: fashion-mnist/test/9/2224.png
#   inflating: fashion-mnist/test/9/3269.png
#   inflating: fashion-mnist/test/9/4794.png
#   inflating: fashion-mnist/test/9/2531.png

# %%
#--- Buscamos las direcciones de cada archivo de imagen
from glob import glob

train_files = glob('./fashion-mnist/train/*/*.png')
valid_files = glob('./fashion-mnist/valid/*/*.png')
test_files = glob('./fashion-mnist/test/*/*.png')

train_files[0]
# Out:
# './fashion-mnist/train/8/27542.png'

# %%
#--- Ordenamos los datos de forma aleatoria para evitar sesgos
import numpy as np

np.random.shuffle(train_files)
np.random.shuffle(valid_files)
np.random.shuffle(test_files)

len(train_files), len(valid_files), len(test_files)
# Out:
# (55000, 10000, 5000)

# %%
#--- Cargamos los datos de entrenamiento en listas
from PIL import Image

N_train = len(train_files)
X_train = []
Y_train = []

for i, train_file in enumerate(train_files):
  Y_train.append( int(train_file.split('/')[3]) )
  X_train.append(np.array(Image.open(train_file)))

# %%
#--- Cargamos los datos de validación en listas
N_valid = len(valid_files)
X_valid = []
Y_valid = []

for i, valid_file in enumerate(valid_files):
  Y_valid.append( int(valid_file.split('/')[3]) )
  X_valid.append( np.array(Image.open(valid_file)) )

# %%
#--- Cargamos los datos de testeo en listas
N_test = len(test_files)
X_test = []
Y_test = []

for i, test_file in enumerate(test_files):
  Y_test.append( int(test_file.split('/')[3]) )
  X_test.append( np.array(Image.open(test_file)) )

# %%
#-- Visualizamos los datos
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,8))
for i in range(4):
  plt.subplot(2,2,i+1)
  plt.imshow(X_test[i*15])
  plt.title(Y_test[i*15])
  plt.axis(False)
plt.show()

# %%
fashion_dict = {'0':'T-shirt/top',
                '1': 'Trouser',
                '2': 'Pullover',
                '3': 'Dress',
                '4': 'Coat',
                '5': 'Sandal',
                '6': 'Shirt',
                '7': 'Sneaker',
                '8': 'Bag',
                '9': 'Ankle boot'}

# %%
#--- Convetimos las listas con los datos a tensores de torch
import torch
from torch.autograd import Variable


X_train = Variable(torch.from_numpy(np.array(X_train))).float()
Y_train = Variable(torch.from_numpy(np.array(Y_train))).long()

X_valid = Variable(torch.from_numpy(np.array(X_valid))).float()
Y_valid = Variable(torch.from_numpy(np.array(Y_valid))).long()

X_test = Variable(torch.from_numpy(np.array(X_test))).float()
Y_test = Variable(torch.from_numpy(np.array(Y_test))).long()

X_train.data.size()
# Out:
# torch.Size([55000, 28, 28])

# %%
import torch

batch_size = 32

train_ds = torch.utils.data.TensorDataset(X_train, Y_train)
train_dl = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True)

# %%
#--- Definimos la CNN

model = torch.nn.Sequential(
  torch.nn.Conv2d(1, 16, kernel_size=5, stride=1, padding=2),
  # ( (28-5+2*2)/1 ) + 1 = 28   -> 28*28*16

  torch.nn.ReLU(),

  torch.nn.MaxPool2d(kernel_size=2),
  # 28/2 = 14                 -> 14*14*16

  torch.nn.Dropout(p=0.2),

  torch.nn.Conv2d(16, 32, kernel_size=5, stride=1, padding=2),
  # ( (14-5+2*2)/1 ) + 1 = 14   -> 14*14*32

  torch.nn.ReLU(),

  torch.nn.MaxPool2d(kernel_size=2),
  # 14/2 = 7                 -> 7*7*32

  torch.nn.Dropout(p=0.2), 

  torch.nn.Flatten(),
  torch.nn.Linear(7*7*32, 10)
)
model
# Out:
# Sequential(
#   (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (1): ReLU()
#   (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): Dropout(p=0.2, inplace=False)
#   (4): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (5): ReLU()
#   (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (7): Dropout(p=0.2, inplace=False)
#   (8): Flatten(start_dim=1, end_dim=-1)
#   (9): Linear(in_features=1568, out_features=10, bias=True)
# )

# %%
#--- Definimos los criterios de evaluación y el optmizador

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001, weight_decay=0.1)

# %%
# !pip install hiddenlayer
# Out:
# Requirement already satisfied: hiddenlayer in /usr/local/lib/python3.7/dist-packages (0.3)

# %%
#--- Visualizamos la estructura de nuestra CNN

import hiddenlayer as hl

hl.build_graph(model, torch.zeros([32,1,28,28]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /usr/local/lib/python3.7/dist-packages/torch/onnx/symbolic_helper.py:715: UserWarning: ONNX export mode is set to inference mode, but operator dropout is set to training  mode. The model will be exported in inference, as specified by the export mode.
#   training_mode + ", as specified by the export mode.")

# %%
from sklearn.metrics import confusion_matrix

def CM(Y_true, Y_pred, classes, lclasses=None):
  fig = plt.figure(figsize=(10, 10))
  cm = confusion_matrix(Y_true, Y_pred)
  if lclasses == None:
    lclasses = np.arange(0,classes)
  cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
  cmap=plt.cm.Blues
  ax = fig.add_subplot(1,1,1)
  im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
  ax.figure.colorbar(im, ax=ax, pad=0.01, shrink=0.86)
  ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]),xticklabels=lclasses, yticklabels=lclasses)
  ax.set_xlabel("Predicted",size=20)
  ax.set_ylabel("True",size=20)
  ax.set_ylim(classes-0.5, -0.5)

  plt.setp(ax.get_xticklabels(), size=12)
  plt.setp(ax.get_yticklabels(), size=12)

  fmt = '.2f'
  thresh = cm.max()/2.
  for i in range(cm.shape[0]):
      for j in range(cm.shape[1]):
          ax.text(j, i, format(cm[i, j], fmt),ha="center", va="center",size=15 , color="white" if cm[i, j] > thresh else "black")

  plt.show()

# %%
#--- Entrenamos la CNN

from sklearn.metrics import f1_score

n_epoch = 2

history = hl.History()
canvas = hl.Canvas()

iter = 0

for epoch in range(n_epoch):
  for batch_id, (X_train_batch, Y_train_batch) in enumerate(train_dl):
    model.train()
    #print(X_train_batch.size())
    Xtr = X_train_batch.unsqueeze(1)
    #print(Xtr.size())
    Y_pred = model(Xtr)

    loss = criterion(Y_pred,Y_train_batch)

    Y_pred = torch.argmax(Y_pred, 1)
    f1 = f1_score(Y_train_batch, Y_pred, average='macro')    

    acc = sum(Y_train_batch == Y_pred)/len(Y_pred)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    iter += 1

    if iter%10 == 0:
        #-- Visualizamos la evolución de los score loss y accuracy
        history.log((epoch+1, iter), loss=loss, accuracy=acc)
        with canvas:
          canvas.draw_plot(history["loss"])
          canvas.draw_plot(history["accuracy"])

# %%
#-- Visualizando los mapas de características de la primera capa convolucional
kernels = list(model.children())[4].weight.detach()

fig = plt.figure(figsize=(16,4))
k = 0
for i in range(kernels[0].size(0)):
    plt.subplot(2,8,k+1)
    plt.imshow(kernels[0][i].squeeze())
    k += 1
plt.show()

# %%
#-- Evaluamos el modelo con nuestro set de entrenamiento

model.eval()
Xts = X_test.unsqueeze(1)
Y_pred = model(Xts)  
loss = criterion(Y_pred,Y_test)

Y_pred = torch.argmax(Y_pred, 1)
f1 = f1_score(Y_test, Y_pred, average='macro')

acc = sum(Y_test == Y_pred)/len(Y_pred)

print( 'Loss:{:.2f}, F1:{:.2f}, Acc:{:.2f}'.format(loss.item(), f1, acc ) )
# Out:
# Loss:0.35, F1:0.88, Acc:0.88

# %%
CM(Y_test, Y_pred, 10, list(fashion_dict.values()))
